# %%
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sns
sns.set()

# %%
path_test_regression = r'G:\Study\Statistics\test regression.csv'
data = pd.read_csv(path_test_regression)

# %%
data
# Out:
#          a      b
# 0        1      2
# 1        2      3
# 2        3      5
# 3        4      7
# 4        5     11
# 5        6     13
# 6        7     17
# 7        8     19
# 8        9     23
# 9       10     29
# 10      11     31
# 11      12     37
# 12      13     41
# 13      14     43
# 14      15     47
# 15      16     53
# 16      17     59
# 17      18     61
# 18      19     67
# 19      20     71
# 20      21     73
# 21      22     79
# 22      23     83
# 23      24     89
# 24      25     97
# 25      26    101
# 26      27    103
# 27      28    107
# 28      29    109
# 29      30    113
# ...    ...    ...
# 9562  9563  99679
# 9563  9564  99689
# 9564  9565  99707
# 9565  9566  99709
# 9566  9567  99713
# 9567  9568  99719
# 9568  9569  99721
# 9569  9570  99733
# 9570  9571  99761
# 9571  9572  99767
# 9572  9573  99787
# 9573  9574  99793
# 9574  9575  99809
# 9575  9576  99817
# 9576  9577  99823
# 9577  9578  99829
# 9578  9579  99833
# 9579  9580  99839
# 9580  9581  99859
# 9581  9582  99871
# 9582  9583  99877
# 9583  9584  99881
# 9584  9585  99901
# 9585  9586  99907
# 9586  9587  99923
# 9587  9588  99929
# 9588  9589  99961
# 9589  9590  99971
# 9590  9591  99989
# 9591  9592  99991
#
# [9592 rows x 2 columns]

# %%
data.describe()
# Out:
#                  a             b
# count  9592.000000   9592.000000
# mean   4796.500000  47372.449646
# std    2769.116225  29412.066406
# min       1.000000      2.000000
# 25%    2398.750000  21378.500000
# 50%    4796.500000  46405.000000
# 75%    7194.250000  72734.500000
# max    9592.000000  99991.000000

# %%
y = data['b']
x1 = data['a']

# %%
plt.scatter(x1,y)
plt.xlabel('a',fontsize=20)
plt.ylabel('b',fontsize=20)
plt.show()

# %%
x = sm.add_constant(x1)
results = sm.OLS(y,x).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      b   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.999
# Method:                 Least Squares   F-statistic:                 8.011e+06
# Date:                Mon, 05 Nov 2018   Prob (F-statistic):               0.00
# Time:                        10:51:55   Log-Likelihood:                -80031.
# No. Observations:                9592   AIC:                         1.601e+05
# Df Residuals:                    9590   BIC:                         1.601e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -3542.9344     20.771   -170.573      0.000   -3583.649   -3502.219
# a             10.6151      0.004   2830.446      0.000      10.608      10.622
# ==============================================================================
# Omnibus:                     1103.064   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1521.923
# Skew:                           0.965   Prob(JB):                         0.00
# Kurtosis:                       3.282   Cond. No.                     1.11e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.11e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
plt.scatter(x1,y)
yhat = 10.6151*x1 - 3542.9344
fig = plt.plot(x1,yhat,lw=4,c='orange',label='regression line')
plt.xlabel('a',fontsize=20)
plt.ylabel('b',fontsize=20)
plt.show()
